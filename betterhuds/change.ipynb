# %%
from categories import categories
# %%capture new_recipes --no-stderr
# Out:
# UsageError: Line magic function `%%capture` not found.

# %%
new_categories = {}
for item in categories: 
    new_categories[item["id"]] = item["name"]
new_categories
# Out:
# {1: 'Breakfast Meats',
#  2: 'Breakfast Entrees',
#  3: 'Breakfast Bakery',
#  4: 'MISC',
#  5: 'Bagel',
#  6: 'Scramble Bowl',
#  7: "Today's Soup",
#  9: 'Brunch',
#  10: 'Salad Bar',
#  11: 'Sand/ Deli',
#  12: 'Entrees',
#  13: 'Veg, Vegan',
#  14: 'Starch And Potatoes',
#  15: 'Vegetables',
#  16: 'Plant protein',
#  17: 'Halal',
#  18: 'Desserts',
#  19: 'From the Grill',
#  20: 'Sides',
#  21: 'Delish',
#  22: 'Brown Rice station',
#  23: 'Build Your Own',
#  24: 'Special Bars Board Menu',
#  25: 'Culinary Display',
#  26: 'Entree Salads',
#  27: 'In Addition at Annenberg',
#  28: 'Bistro Bowl',
#  29: 'Fruit Forward',
#  31: 'Chefs Choice',
#  32: 'Fresh Fruit',
#  33: 'Sandwich Selections',
#  34: 'Vegetarian Sandwich Selections',
#  35: 'Cheese Choices',
#  36: 'Extras',
#  37: 'Bread Choices',
#  38: 'HALAL',
#  40: 'Festive Meals',
#  42: 'Fly-By',
#  43: 'Fly-By Sandwiches and Salads',
#  45: 'Chili Bar',
#  46: 'Whole Grain Pasta Bar',
#  47: 'Comfort Foods',
#  51: 'CR Purchased Bottled Beverages',
#  52: 'CR Baked Goods/Desserts',
#  53: 'CR Snacks/Candy',
#  54: 'Daily Bowl',
#  55: 'International Cuisine',
#  57: 'Global Comforts',
#  58: 'Deli Sandwiches',
#  59: 'VEGETARIAN ENTREE',
#  60: 'Entrees',
#  61: 'Starch and Vegetable Selection',
#  62: 'Daily Soups',
#  63: 'CR Beverages Prepared',
#  64: 'Salad Bar',
#  65: 'Breakfast',
#  66: 'Misc',
#  67: 'Grains',
#  68: 'From the Grill',
#  69: 'Plant forward',
#  71: 'Pizza',
#  72: 'FRESH FIRED',
#  73: 'CR Other Resale Items',
#  74: 'CR Salty Snacks',
#  75: 'Odwalla Juices',
#  77: 'Cereals',
#  78: 'Bagels',
#  80: 'PANINIS',
#  81: 'SPECIALTY SANDWICHES',
#  83: 'Yogurts, Jams and Spreads',
#  84: 'Dressings',
#  85: 'Beverages',
#  86: 'Roasted Vegetables',
#  87: 'Bag Meal Breakfast Options',
#  88: 'Heart of the Plate',
#  89: 'Special Bar',
#  90: 'Brain Break',
#  91: 'Bag Meal Specialty Sandwiches',
#  92: 'Bag Meal Salads',
#  93: 'Bag Meal Build Your Own',
#  94: 'Bag MeaL Bread Choices',
#  95: 'Bag Meal Cheese Choices',
#  96: 'Bagged Meal Sides',
#  97: 'Bagged Meal Condiments',
#  98: 'Bag Meal Beverages',
#  99: 'Add-ons'}

# %%
from categories import recipes

# %%
recipes
# Out:
# [{'allergens': ['Tree Nuts'],
#   'calories': 170,
#   'calories_from_fat': 54,
#   'cholesterol': {'amount': '20mg', 'percent': 7.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10010,
#   'information': None,
#   'ingredients': 'Thai Chicken Curry Soup (Chicken Stock (Water, Chicken Bones, Onions, Celery, Carrots, Sea Salt, Garlic, Parsley, White Pepper, Thyme, Bay Leaves, Marjoram), Chicken Meat, Green Peppers, Onions, Coconut Milk (Coconut, Water), Brown Rice, Red Bell Peppers, Water, Bamboo Shoots (Bamboo Shoots, Water), Rice Flour, Rice Starch, Dried Lemon Grass, Ginger, Sea Salt, Garlic, Chicken Fat, Red Curry Paste (Red Chili, Salt, Lemon Grass, Onion, Garlic, Galangal, Dextrose, Makrut Lime Peel, Cumin Powder, Paprika Oleoresin, coriander), Scallions, Garlic Chili Pepper Sauce (Red Chili, Sugar, Garlic, Salt, Distilled Vinegar, Sodium Benzoate [a preservative], Xanthan Gum [a stabilizer]), Mustard Flour, Coriander, Sesame Oil, Paprika (for color), Sugar, Cayenne Pepper, White Pepper, Lime Oil.)',
#   'name': 'Thai Chicken Soup with Red Curry',
#   'protein': {'amount': '8g', 'percent': 16.0},
#   'sat_fat': {'amount': '3g', 'percent': 15.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '729.4mg', 'percent': 36.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '22g', 'percent': 7.0},
#   'total_fat': {'amount': '6g', 'percent': 8.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 130,
#   'calories_from_fat': 27,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '5g', 'percent': 20.0},
#   'id': 10011,
#   'information': None,
#   'ingredients': 'Black Bean Soup (Black Beans, Water, Orange Juice, Onions, Roasted Red Peppers, Roasted Sweet Corn, Green Chile Peppers, Tomato Purée (tomatoes, salt, citric acid), Corn Oil, Sea Salt, Lime Juice Concentrate (100%), Cilantro, Cumin, Garlic, Chili Powder (spices, sea salt, garlic powder), Ancho Chile Powder, Smoked Paprika, Dried Pasilla Pepper, Dried Oregano, Bay Leaf.)',
#   'name': 'Black Bean Soup',
#   'protein': {'amount': '6g', 'percent': 12.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '649.4mg', 'percent': 32.0},
#   'sugars': {'amount': '4g'},
#   'total_carb': {'amount': '20g', 'percent': 7.0},
#   'total_fat': {'amount': '3g', 'percent': 4.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Milk', 'Wheat'],
#   'calories': 240,
#   'calories_from_fat': 135,
#   'cholesterol': {'amount': '64.9mg', 'percent': 22.0},
#   'dietary_fiber': {'amount': '0g'},
#   'id': 10012,
#   'information': None,
#   'ingredients': 'Buffalo Chicken Soup (Chicken Stock, Chicken Meat, Carrots, Celery, Onions, Blue Cheese (milk, cheese cultures, salt, enzymes), Butter (cream, salt), Wheat Flour, Garlic, Cider Vinegar, Water, Paprika, Sea Salt, Rice Starch, Pepper Sauce (distilled vinegar, red pepper, salt), Spices.)',
#   'name': 'Buffalo Chicken Soup',
#   'protein': {'amount': '13g', 'percent': 25.0},
#   'sat_fat': {'amount': '9g', 'percent': 45.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '659.4mg', 'percent': 33.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '14g', 'percent': 5.0},
#   'total_fat': {'amount': '15g', 'percent': 20.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Milk'],
#   'calories': 320,
#   'calories_from_fat': 216,
#   'cholesterol': {'amount': '69.9mg', 'percent': 23.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10013,
#   'information': None,
#   'ingredients': 'Broccoli and Cheddar Soup (Water, Cheddar Cheese (milk, cheese cultures, salt, enzymes), Broccoli, Light Cream (milk, cream), Rice Flour, Butter (cream, salt), Onions, Olive Oil, Sea Salt, Garlic, Spices, Annatto (for color).)',
#   'name': 'Broccoli And Cheddar Soup',
#   'protein': {'amount': '11g', 'percent': 22.0},
#   'sat_fat': {'amount': '15g', 'percent': 75.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '759.3mg', 'percent': 38.0},
#   'sugars': {'amount': '1g'},
#   'total_carb': {'amount': '16g', 'percent': 5.0},
#   'total_fat': {'amount': '24g', 'percent': 32.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': True},
#  {'allergens': ['Eggs', 'Wheat'],
#   'calories': 90,
#   'calories_from_fat': 18,
#   'cholesterol': {'amount': '25mg', 'percent': 8.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10015,
#   'information': None,
#   'ingredients': 'Chicken Noodle Soup (Chicken Stock (water, chicken, onions, celery, carrots, sea salt, garlic, parsley, white pepper, thyme, bay leaves, marjoram), Mafalda Noodles (semolina, durum flour, eggs, egg whites), Chicken Meat, Carrots, Celery, Onions, Sea Salt, Chicken Fat, Spices.)',
#   'name': 'Chicken Noodle Soup',
#   'protein': {'amount': '7g', 'percent': 14.0},
#   'sat_fat': {'amount': '1g', 'percent': 5.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '659.4mg', 'percent': 33.0},
#   'sugars': {'amount': '2g'},
#   'total_carb': {'amount': '10g', 'percent': 3.0},
#   'total_fat': {'amount': '2g', 'percent': 3.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Milk'],
#   'calories': 180,
#   'calories_from_fat': 90,
#   'cholesterol': {'amount': '30mg', 'percent': 10.0},
#   'dietary_fiber': {'amount': '4g', 'percent': 16.0},
#   'id': 10016,
#   'information': None,
#   'ingredients': 'Buttermilk & Apple Soup (Butternut Squash, Chicken Stock (water, chicken, onions, celery, carrots, sea salt, garlic, parsley, white pepper, thyme, bay leaves, marjoram), Light Cream (milk, cream), Apples, Onions, Butter (cream, salt), Honey, Amontillado Sherry (grape wine [amontillado medium], alcohol), Sea Salt, Chicken Fat, Spices. Contains milk ingredients Contains: Milk and Alcohol Gluten Free)',
#   'name': 'Butternut Squash and Apple Soup',
#   'protein': {'amount': '3g', 'percent': 6.0},
#   'sat_fat': {'amount': '6g', 'percent': 30.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '439.6mg', 'percent': 22.0},
#   'sugars': {'amount': '10g'},
#   'total_carb': {'amount': '21g', 'percent': 7.0},
#   'total_fat': {'amount': '10g', 'percent': 13.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 120,
#   'calories_from_fat': 27,
#   'cholesterol': {'amount': '20mg', 'percent': 7.0},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 10017,
#   'information': None,
#   'ingredients': 'Chicken Tortilla Soup (Chicken Stock (Water, Chicken Bones, Onions, Celery, Carrots, Sea Salt, Garlic, Parsley, White Pepper, Thyme, Bay Leaves, Marjoram), Diced Tomatoes (Tomatoes, Tomato Juice, Salt, Citric Acid), Chicken Meat, Corn, Onions, Green Peppers, Corn Tortilla Chips (Corn Flour, Sunflower and/or Safflower Oil, Sea Salt), Green Chili Peppers, Sea Salt, Corn Oil, Cilantro, Cumin, Paprika (for color), Chili Powder (Spices, Sea Salt, Garlic Powder), Pepper Sauce (Distilled Vinegar, Red Pepper, Salt), Dried Oregano, Lime Oil, Cayenne Ground Pepper.)',
#   'name': 'Chicken Tortilla Soup',
#   'protein': {'amount': '8g', 'percent': 16.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '679.4mg', 'percent': 34.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '15g', 'percent': 5.0},
#   'total_fat': {'amount': '3g', 'percent': 4.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 90,
#   'calories_from_fat': 36,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 10018,
#   'information': None,
#   'ingredients': 'Tomato Basil Soup (Chopped Tomatoes (tomatoes, salt, naturally derived citric acid), Vegetable Stock (water, onions, cabbage, celery, mushrooms, carrots, turnips, black peppercorn, mustard seed, dill weed, thyme, bay leaves, marjoram), Onions, Carrots, Tomato Paste (tomatoes, naturally derived citric acid), Basil, Extra Virgin Olive Oil, Garlic, Sea Salt, Spices.)',
#   'name': 'Tomato Basil Soup',
#   'protein': {'amount': '2g', 'percent': 4.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '589.5mg', 'percent': 29.0},
#   'sugars': {'amount': '8g'},
#   'total_carb': {'amount': '13g', 'percent': 4.0},
#   'total_fat': {'amount': '4g', 'percent': 5.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Milk', 'Soybeans'],
#   'calories': 160,
#   'calories_from_fat': 36,
#   'cholesterol': {'amount': '5mg', 'percent': 2.0},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 10019,
#   'information': None,
#   'ingredients': 'French Onion Soup (Water, Onions, Beef Stock, Burgundy Wine, Brandy, Sea Salt, Butter, Soybean Oil, Caramel, Spices.)',
#   'name': 'French Onion Soup',
#   'protein': {'amount': '9g', 'percent': 18.0},
#   'sat_fat': {'amount': '1g', 'percent': 5.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '949.2mg', 'percent': 47.0},
#   'sugars': {'amount': '8g'},
#   'total_carb': {'amount': '18g', 'percent': 6.0},
#   'total_fat': {'amount': '4g', 'percent': 5.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Milk'],
#   'calories': 230,
#   'calories_from_fat': 99,
#   'cholesterol': {'amount': '35mg', 'percent': 12.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10020,
#   'information': None,
#   'ingredients': 'Corn Chowder (Corn (corn, water, salt), Vegetable Stock (contains mustard seed), Potatoes, Light Cream (milk, cream), Onions, Butter (cream, salt), Water, Rice Flour, Celery, Corn Starch, Sea Salt, Sugar, Spices.)',
#   'name': 'Corn Chowder',
#   'protein': {'amount': '3g', 'percent': 6.0},
#   'sat_fat': {'amount': '7g', 'percent': 35.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '639.4mg', 'percent': 32.0},
#   'sugars': {'amount': '6g'},
#   'total_carb': {'amount': '30g', 'percent': 10.0},
#   'total_fat': {'amount': '11g', 'percent': 15.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': True},
#  {'allergens': ['Crustacean Shellfish', 'Fish', 'Milk', 'Soybeans', 'Wheat'],
#   'calories': 340,
#   'calories_from_fat': 216,
#   'cholesterol': {'amount': '89.9mg', 'percent': 30.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10021,
#   'information': None,
#   'ingredients': 'New England Clam Chowder (Light Cream (Milk, Cream), Clam Meat, Potatoes, Fish Stock (Water, Cod, Haddock, Onions, Celery, Black Pepper, Thyme, Mustard Seed, Bay Leaves), Onions, Wheat Flour, Soybean Oil, Butter (Cream, Salt), Clam Broth (Dehydrated Clam Broth, Maltodextrin), Sea Salt, Celery, Salt Pork (Pork, Sea Salt), Spices, Worcestershire Sauce (Distilled White Vinegar, Molasses, Water, Sugar, Onions, Anchovies, Salt, Garlic, Coves, Tamarind Extract, Natural Flavorings, Chili Pepper Extract), Garlic.)',
#   'name': 'New England Clam Chowder',
#   'protein': {'amount': '10g', 'percent': 20.0},
#   'sat_fat': {'amount': '13g', 'percent': 65.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '709.4mg', 'percent': 35.0},
#   'sugars': {'amount': '5g'},
#   'total_carb': {'amount': '21g', 'percent': 7.0},
#   'total_fat': {'amount': '24g', 'percent': 32.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Eggs', 'Milk', 'Wheat'],
#   'calories': 130,
#   'calories_from_fat': 72,
#   'cholesterol': {'amount': '15mg', 'percent': 5.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10022,
#   'information': None,
#   'ingredients': "Italian Wedding Soup w/Meatballs (Chicken Stock (Water, Chicken, Onions, Celery, Carrots, Sea Salt, Garlic, Parsley, White Pepper, Thyme, Bay Leaves, Marjoram), Meatballs (Beef, Water, Egg Whites, Bread Crumbs [Wheat Flour, Salt, Yeast], Romano Cheese [Sheep's and/or Cow's Milk, Rennet, Salt, Cheese Cultures, Enzymes], Dehydrated Onion, Evaporated Cane Syrup, Salt, Natural Flavors), Onions, Acini di Pepe Pasta (Semolina [Wheat], Egg Whites), Spinach, Escarole, Extra Virgin Olive Oil, Basil, Garlic, Sea Salt, Thyme, Canola Oil, Spices, Lemon Juice.)",
#   'name': 'Italian Meatball Soup',
#   'protein': {'amount': '7g', 'percent': 14.0},
#   'sat_fat': {'amount': '3g', 'percent': 15.0},
#   'serving_size': '8 fl. oz',
#   'sodium': {'amount': '529.5mg', 'percent': 26.0},
#   'sugars': {'amount': '2g'},
#   'total_carb': {'amount': '10g', 'percent': 3.0},
#   'total_fat': {'amount': '8g', 'percent': 11.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Soybeans'],
#   'calories': 110,
#   'calories_from_fat': 36,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3g', 'percent': 12.0},
#   'id': 10023,
#   'information': None,
#   'ingredients': 'Carrot Ginger Soup (Carrots, Water, Orange Juice, Onions, White Rice, Corn Oil, Ginger, Garlic, Sesame Oil, Organic Tamari Sauce (water, organic soybeans, salt), Sea Salt, Spices.)',
#   'name': 'Carrot Ginger Sesame Soup',
#   'protein': {'amount': '2g', 'percent': 4.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '299.7mg', 'percent': 15.0},
#   'sugars': {'amount': '7g'},
#   'total_carb': {'amount': '18g', 'percent': 6.0},
#   'total_fat': {'amount': '4g', 'percent': 5.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': ['Milk'],
#   'calories': 90,
#   'calories_from_fat': 18,
#   'cholesterol': {'amount': '15mg', 'percent': 5.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10024,
#   'information': None,
#   'ingredients': 'Cream of Chicken with Wild Rice (Chicken Stock (Water, Chicken, Onions, Celery, Carrots, Sea Salt, Garlic, Parsley, White Pepper, Thyme, bay leaves Marjoram), Chicken (dark & light meat), Chicken Fat, Light Cream (milk, cream), Onions, Celery, Carrots, Rice Flour, Water, Mushrooms, Wild Rice, Sherry Wine (contains sulfites), Rice Starch, White Rice, Sea Salt, Garlic, Spices, Pepper Sauce (distilled vinegar, red pepper, salt).)',
#   'name': 'Cream of Chicken and Wild Rice Soup',
#   'protein': {'amount': '7g', 'percent': 14.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '559.5mg', 'percent': 28.0},
#   'sugars': {'amount': '2g'},
#   'total_carb': {'amount': '11g', 'percent': 4.0},
#   'total_fat': {'amount': '2g', 'percent': 3.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Milk', 'Soybeans', 'Wheat'],
#   'calories': 240,
#   'calories_from_fat': 153,
#   'cholesterol': {'amount': '25mg', 'percent': 8.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10025,
#   'information': None,
#   'ingredients': 'Hungarian Mushroom Soup (Water, Mushrooms, Light Cream, Beef Stock, Wheat Flour, Onions, Carrots, Soybean Oil, Madeira Wine, contains sulfites), Sour Cream (cultured light cream, nonfat milk, enzymes), Sea Salt, Butter (cream, salt), Paprika (for color), Spices. Contains Milk, Wheat.Soybean oil, Alcohol)',
#   'name': 'Hungarian Mushroom soup',
#   'protein': {'amount': '6g', 'percent': 12.0},
#   'sat_fat': {'amount': '6g', 'percent': 30.0},
#   'serving_size': '8 fl. oz',
#   'sodium': {'amount': '669.4mg', 'percent': 33.0},
#   'sugars': {'amount': '4g'},
#   'total_carb': {'amount': '16g', 'percent': 5.0},
#   'total_fat': {'amount': '17g', 'percent': 23.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Crustacean Shellfish', 'Fish'],
#   'calories': 120,
#   'calories_from_fat': 27,
#   'cholesterol': {'amount': '15mg', 'percent': 5.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10026,
#   'information': None,
#   'ingredients': 'Manhattan Clam Chowder (Tomato Strips (tomatoes, salt, citric acid), Fish Stock, Clam Meat, Potatoes, Water, Tomato Paste (tomatoes, citric acid), Onions, Celery, Scallions, Olive Oil, Clam Broth (dehydrated clam broth, maltodextrin), Garlic, Parsley, Sea Salt, Spices, Pepper Sauce (distilled vinegar, red pepper, salt).)',
#   'name': 'Manhattan Clam Chowder',
#   'protein': {'amount': '8g', 'percent': 16.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '649.4mg', 'percent': 32.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '16g', 'percent': 5.0},
#   'total_fat': {'amount': '3g', 'percent': 4.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Milk'],
#   'calories': 340,
#   'calories_from_fat': 180,
#   'cholesterol': {'amount': '64.9mg', 'percent': 22.0},
#   'dietary_fiber': {'amount': '1g', 'percent': 4.0},
#   'id': 10027,
#   'information': None,
#   'ingredients': 'Loaded Potato Soup (Potatoes, Water, Chicken Stock, (Chicken Onions, celery, carrots, sea salt, garlic, parsley, white pepper, thyme, leaves, marjoram), Cheddar Cheese (milk, cheese cultures, salt, enzymes), Uncured Bacon with no nitrites or nitrates added (pork, sea salt, raw sugar, spices), Light Cream (milk, cream), Leeks, Celery, Beef Stock, Onions, Rice Starch, Scallions, Sea Salt, Garlic, Spices. Contains Milk.Pork)',
#   'name': 'Loaded Potato Soup',
#   'protein': {'amount': '17g', 'percent': 33.0},
#   'sat_fat': {'amount': '11g', 'percent': 55.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '869.2mg', 'percent': 43.0},
#   'sugars': {'amount': '2g'},
#   'total_carb': {'amount': '22g', 'percent': 7.0},
#   'total_fat': {'amount': '20g', 'percent': 27.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Crustacean Shellfish', 'Wheat'],
#   'calories': 140,
#   'calories_from_fat': 45,
#   'cholesterol': {'amount': '30mg', 'percent': 10.0},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 10028,
#   'information': None,
#   'ingredients': 'Shrimp & Sausage Gumbo (Water, Chicken Stock (water, chicken bones, onions, celery, carrots, sea salt, garlic, parsley, white pepper, thyme, bay leaves, marjoram), Diced Tomatoes (tomatoes, tomato juice, salt, citric acid), Celery, Green Peppers, Onions, Okra, Smoke Andouille Sausage (pork, seasoning [sea salt, spices, brown sugar, native potato starch, paprika, garlic, natural cure {blend of celery powder, sea salt}] water), Shrimp, Parboiled Long Grain Rice, Wheat Flour, Pork Fat, Tomato Puree (tomatoes, salt, citric acid), Chicken Fat, Sea Salt, Rice Starch, Parsley, Pepper Sauce (distilled vinegar, red pepper, salt), Garlic, Clam Concentrate (concentrated clam broth, salt), Paprika (for color), Gumbo File, Dried Thyme, Black Pepper, Bay Leaves, Cayenne Ground Pepper, Red Pepper Flakes, Cloves.)',
#   'name': 'Shrimp and Sausage Gumbo',
#   'protein': {'amount': '7g', 'percent': 14.0},
#   'sat_fat': {'amount': '1g', 'percent': 5.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '709.4mg', 'percent': 35.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '17g', 'percent': 6.0},
#   'total_fat': {'amount': '5g', 'percent': 7.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Wheat'],
#   'calories': 140,
#   'calories_from_fat': 36,
#   'cholesterol': {'amount': '25mg', 'percent': 8.0},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 10029,
#   'information': None,
#   'ingredients': 'Turkey Gumbo Soup (Chicken Stock, Tomato Strips (tomatoes, salt, citric acid), Okra, Onions, Turkey Thigh Meat, Carrots, Celery, White Rice, Turkey Breast Meat, Green Peppers, Chicken Fat, Sherry Wine (contains sulfites), Wheat Flour, Sea Salt, Garlic Spices, Parsley, Pepper Sauce (distilled vinegar, red pepper, salt), Paprika.)',
#   'name': 'Turkey Gumbo',
#   'protein': {'amount': '11g', 'percent': 22.0},
#   'sat_fat': {'amount': '1g', 'percent': 5.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '649.4mg', 'percent': 32.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '15g', 'percent': 5.0},
#   'total_fat': {'amount': '4g', 'percent': 5.0},
#   'trans_fat': None,
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Eggs', 'Wheat'],
#   'calories': 80,
#   'calories_from_fat': 18,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3g', 'percent': 12.0},
#   'id': 10030,
#   'information': None,
#   'ingredients': 'Minestrone Soup (Vegetable Stock (Water, Onions, Cabbage, Celery, Mushrooms, Carrots, Turnips, Black Peppercorns, Mustard Seed, Dill Weed, Thyme, Bay Leaves, Marjoram), Diced Tomatoes (Tomatoes, Salt, Naturally Derived Citric Acid), Ground Tomatoes (Tomatoes, Salt, Naturally Derived Citric Acid), Onions, Zucchini, Great Northern Beans, Savoy Cabbage, Garbanzo Beans, Carrots, Celery, White Wine (Contains Sulfites), Ditalini Pasta (Semolina, Egg Whites), Basil, Canola Oil, Sea Salt, Garlic, Sugar, Extra Virgin Olive Oil, Spices.)',
#   'name': 'Minestrone Soup',
#   'protein': {'amount': '3g', 'percent': 6.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 fl. oz',
#   'sodium': {'amount': '449.6mg', 'percent': 22.0},
#   'sugars': {'amount': '5g'},
#   'total_carb': {'amount': '14g', 'percent': 5.0},
#   'total_fat': {'amount': '2g', 'percent': 3.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': True},
#  {'allergens': ['Eggs', 'Milk', 'Wheat'],
#   'calories': 160,
#   'calories_from_fat': 54,
#   'cholesterol': {'amount': '10mg', 'percent': 3.0},
#   'dietary_fiber': {'amount': '8g', 'percent': 32.0},
#   'id': 10031,
#   'information': None,
#   'ingredients': 'Pasta Fagioli Soup (Chicken Stock, (Chicken, Onions, Celery, Carrots, Seasalt, Garlic, Parsley, WhitePepper, Thyme, Bay Leaves, marjoram), White Navy Beans, Diced Tomatoes (tomatoes, tomato juice, salt, naturally derived citric acid), Leeks, Spinach, Onions, Celery, Ditalini Pasta (semolina, egg whites), Uncured Bacon with no nitrites or nitrates added (pork, sea salt, raw sugar, spices), Grated Parmesan Cheese (milk, cheese cultures, salt, enzymes), Olive Oil, Extra Virgin Olive Oil, Garlic, Sea Salt, Parsley, Spices.)',
#   'name': 'Pasta Fagioli Soup',
#   'protein': {'amount': '15g', 'percent': 29.0},
#   'sat_fat': {'amount': '2g', 'percent': 10.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '739.3mg', 'percent': 37.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '24g', 'percent': 8.0},
#   'total_fat': {'amount': '6g', 'percent': 8.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 150,
#   'calories_from_fat': 36,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '15g', 'percent': 60.0},
#   'id': 10032,
#   'information': None,
#   'ingredients': 'White Bean and Escarole Soup (White Navy Beans, Vegetable Stock (Water, Onions, Cabbage, Celery, Mushrooms, Carrots, Turnips, Black Peppercorns, Mustard Seed, Dill Weed, Thyme, Bay Leaves, Marjoram), Escarole, Fennel, Onions, Extra Virgin Olive Oil, Lemon Juice, Sea Salt, Basil, Water, Garlic, Corn Starch, Spices, Thyme.)',
#   'name': 'White Bean and Escarole',
#   'protein': {'amount': '10g', 'percent': 20.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 fl. oz',
#   'sodium': {'amount': '729.4mg', 'percent': 36.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '33g', 'percent': 11.0},
#   'total_fat': {'amount': '4g', 'percent': 5.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Milk'],
#   'calories': 110,
#   'calories_from_fat': 27,
#   'cholesterol': {'amount': '15mg', 'percent': 5.0},
#   'dietary_fiber': {'amount': '3g', 'percent': 12.0},
#   'id': 10033,
#   'information': None,
#   'ingredients': 'Vegetable Beef Barley Soup (Beef Stock (beef bones, water), Tomato Strips (tomatoes, salt, citric acid), Angus Beef, Carrots, Onions, Pearl Barley, Green Beans, Peas, Celery, Mushrooms, Leeks, Red Peppers, Butter (cream, salt), Sea Salt, Parsley, Garlic Spices.)',
#   'name': 'Beef Vegetable and Barley',
#   'protein': {'amount': '8g', 'percent': 16.0},
#   'sat_fat': {'amount': '1g', 'percent': 5.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '689.4mg', 'percent': 34.0},
#   'sugars': {'amount': '2g'},
#   'total_carb': {'amount': '13g', 'percent': 4.0},
#   'total_fat': {'amount': '3g', 'percent': 4.0},
#   'trans_fat': None,
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Soybeans'],
#   'calories': 180,
#   'calories_from_fat': 99,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '5g', 'percent': 20.0},
#   'id': 10034,
#   'information': None,
#   'ingredients': 'Lentil Soup (Water, Lentils, Carrots, Onions, Celery, Turnips, Olive Oil, Tomato Paste (Tomatoes, Citric acid), Rice Flour, Soybean Oil, Balsamic Vinegar (Wine Vinegar, Grape Must), Garlic, Sea Salt, Spices, Paprika (For Color), Parsley.)',
#   'name': 'Lentil Soup',
#   'protein': {'amount': '5g', 'percent': 10.0},
#   'sat_fat': {'amount': '1g', 'percent': 5.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '609.5mg', 'percent': 30.0},
#   'sugars': {'amount': '4g'},
#   'total_carb': {'amount': '18g', 'percent': 6.0},
#   'total_fat': {'amount': '11g', 'percent': 15.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Milk'],
#   'calories': 270,
#   'calories_from_fat': 117,
#   'cholesterol': {'amount': '64.9mg', 'percent': 22.0},
#   'dietary_fiber': {'amount': '8g', 'percent': 32.0},
#   'id': 10035,
#   'information': None,
#   'ingredients': 'Chicken Chili w/Cilantro Soup (Chicken Meat (Dark and Light Meat), Chicken Stock, (Water, Chicken Bones, Onions, Celery, Carrots, Sea Salt, Garlic, Parsley, White Pepper, Thyme, Bay Leaves, Marjoram), White Navy Beans, Onions, Sour Cream (Cultured Light Cream, Nonfat Milk, Enzymes), Celery, Green Peppers, Chicken Fat, Rice Flour, Sea Salt, Garlic, Garlic Chili Pepper Sauce (Red Chili, Water, Sugar, Garlic, Salt, Distilled Vinegar , Sodium Benzoate [a preservative], Xantham Gum [a stabilizer]), Cumin, Cilantro, Cocoa Powder, Ancho Chili Powder, Cayenne Pepper, Dried Thyme, Dried Oregano, White Pepper.)',
#   'name': 'Chicken Chili with Cilantro',
#   'protein': {'amount': '19g', 'percent': 37.0},
#   'sat_fat': {'amount': '4g', 'percent': 20.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '639.4mg', 'percent': 32.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '24g', 'percent': 8.0},
#   'total_fat': {'amount': '13g', 'percent': 17.0},
#   'trans_fat': None,
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 160,
#   'calories_from_fat': 36,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '4g', 'percent': 16.0},
#   'id': 10036,
#   'information': None,
#   'ingredients': 'Quinoa Sweet Potato w/Black Bean Chili (Water, Sweet Potatoes, Black Beans, Onions, Diced Tomatoes (Tomatoes, Salt, Citric Acid), Red Quinoa, Red Peppers, Yellow Peppers, Orange Juice, Honey, Canola Oil, Lime Juice, Sea Salt, Tomato Paste Tomatoes, Citric Acid), Corn Starch, Garlic, Spices, Cilantro, Paprika (For Color).)',
#   'name': 'Quinoa and Sweet Potato Chili',
#   'protein': {'amount': '4g', 'percent': 8.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '699.4mg', 'percent': 35.0},
#   'sugars': {'amount': '9g'},
#   'total_carb': {'amount': '29g', 'percent': 10.0},
#   'total_fat': {'amount': '4g', 'percent': 5.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 210,
#   'calories_from_fat': 72,
#   'cholesterol': {'amount': '45mg', 'percent': 15.0},
#   'dietary_fiber': {'amount': '7g', 'percent': 28.0},
#   'id': 10037,
#   'information': None,
#   'ingredients': 'Beef Steak Chili (Angus Beef, Ground Tomatoes (tomatoes, salt, citric acid), Onions, Diced Tomatoes (tomatoes, tomato juice, salt, citric acid), Small Red Beans, Green Bell Peppers, Garlic, Chili Powder (chili pepper, spices, salt, dehydrated garlic), Canola Oil, Spices, Sea Salt, Cocoa Powder, Coffee Extract (decaf).)',
#   'name': 'Beef Chili',
#   'protein': {'amount': '18g', 'percent': 35.0},
#   'sat_fat': {'amount': '2g', 'percent': 10.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '579.5mg', 'percent': 29.0},
#   'sugars': {'amount': '7g'},
#   'total_carb': {'amount': '21g', 'percent': 7.0},
#   'total_fat': {'amount': '8g', 'percent': 11.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 140,
#   'calories_from_fat': 18,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '8g', 'percent': 32.0},
#   'id': 10038,
#   'information': None,
#   'ingredients': 'Three Bean chili (Tomatoes (tomatoes, salt, citric acid), Onions, Small Red Beans, Black Beans, Pinto Beans, Water, Organic Corn, Green Chili Peppers, Red Bell Peppers, Yellow Peppers, Garlic, Cilantro, Corn Oil, Ancho Chili Powder, Paprika (for color), Sea Salt, Cumin, Chili Powder (spices, sea salt, garlic powder), Dried Oregano, Pepper Sauce (distilled vinegar, red pepper, salt).)',
#   'name': 'Three Bean Chili',
#   'protein': {'amount': '7g', 'percent': 14.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 fl. oz',
#   'sodium': {'amount': '499.6mg', 'percent': 25.0},
#   'sugars': {'amount': '7g'},
#   'total_carb': {'amount': '27g', 'percent': 9.0},
#   'total_fat': {'amount': '2g', 'percent': 3.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 200,
#   'calories_from_fat': 36,
#   'cholesterol': {'amount': '69.9mg', 'percent': 23.0},
#   'dietary_fiber': {'amount': '6g', 'percent': 24.0},
#   'id': 10039,
#   'information': None,
#   'ingredients': 'Turkey Chili with Beans (Tomatoes (Tomatoes, Salt, Citric acid), Turkey Thigh Meat, Onions, Small Red Beans, Green Peppers, Green Chilies (Green Chile Peppers, Water, Salt, Citric Acid), Tomato Paste (Tomatoes, Naturally derived Citric Acid), Garlic, Spices, Chicken Fat, Paprika (for color), Sea Salt, Chili Powder (Spices, Sea Salt, Garlic Powder), Pepper Sauce (Distilled Vinegar, Red Pepper, Salt).)',
#   'name': 'Turkey and Bean Chili',
#   'protein': {'amount': '22g', 'percent': 43.0},
#   'sat_fat': {'amount': '1g', 'percent': 5.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '549.5mg', 'percent': 27.0},
#   'sugars': {'amount': '7g'},
#   'total_carb': {'amount': '21g', 'percent': 7.0},
#   'total_fat': {'amount': '4g', 'percent': 5.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Eggs', 'Milk', 'Wheat'],
#   'calories': 510,
#   'calories_from_fat': 261,
#   'cholesterol': {'amount': '89.9mg', 'percent': 30.0},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 10040,
#   'information': None,
#   'ingredients': 'Macaroni and Cheese (Water, Elbow Macaroni (Semolina Wheat, Egg Whites), Cheddar Cheese (Milk, Cheese Cultures, Salt, Enzymes), Light Cream (Milk, Cream), Butter (Cream, Salt), Rice Flour, Monterey Jack Cheese (Milk, Cheese Cultures, Salt, Enzymes), Sea Salt, Annatto Seed Powder, Bay Leaves, Nutmeg, White Pepper, Cayenne Ground Pepper.)',
#   'name': 'Macaroni and Cheese',
#   'protein': {'amount': '21g', 'percent': 41.0},
#   'sat_fat': {'amount': '19g', 'percent': 95.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '949.2mg', 'percent': 47.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '42g', 'percent': 14.0},
#   'total_fat': {'amount': '29g', 'percent': 39.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': True},
#  {'allergens': ['Soybeans', 'Wheat'],
#   'calories': 643,
#   'calories_from_fat': 167,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '5.7g', 'percent': 23.0},
#   'id': 10041,
#   'information': None,
#   'ingredients': 'Organic Soy Milk (Organic Soymilk (Filtered Water, Organic Soybeans), Organic Cane Sugar, Calcium Carbonate, Sea Salt, Natural Flavors, Gellan Gum, Vitamin A Palmitate, Vitamin D2, Riboflavin (Vitamin B2), and Vitamin B12.), Pumpkin Filling (Pumpkin), Fettuccini (100% Durum Wheat Semolina, Water. MAY CONTAIN TRACES OF SOY.), Olive Oil (Refined Olive Oil, Extra Virgin Olive Oil, ), All Purpose Flour (Bleached Wheat Flour, Malted Barley Flour, Niacin, Iron, Thiamine Mononitrate, Riboflavin, Folic Acid.), Yeast Flakes (Inactive Dry Yeast, Pyridoxine Hydrochloride (Vitamin B6), Thiamin Hydrochloride (Vitamin B1), Riboflavin (Vitamin B2), Folic Acid (Vitamin B9), Vitamin B12.), Garlic (Garlic), Whole Black Pepper (Black Peppercorns), Kosher Salt (Salt)',
#   'name': 'Vegan Pumpkin Fettuccini Alfredo',
#   'protein': {'amount': '19g', 'percent': 37.0},
#   'sat_fat': {'amount': '2.6g', 'percent': 13.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '99.1mg', 'percent': 5.0},
#   'sugars': {'amount': '10.2g'},
#   'total_carb': {'amount': '103.5g', 'percent': 35.0},
#   'total_fat': {'amount': '18.5g', 'percent': 25.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 156,
#   'calories_from_fat': 47,
#   'cholesterol': {'amount': '20.8mg', 'percent': 7.0},
#   'dietary_fiber': {'amount': '5.2g', 'percent': 21.0},
#   'id': 10042,
#   'information': None,
#   'ingredients': 'SPLIT PEA SOUP W/ HAM (Peas, Onions, Chicken Stock (water, chicken, onions, celery, carrots, sea salt, garlic, parsley, white pepper, thyme, bay leaves, marjoram), Water, Uncured Ham* (pork, water, vinegar, brown sugar, salt, celery powder, natural flavorings, lactic acid starter culture) *no added nitrite or nitrate except for that naturally occurring in celery powder, Carrots, Celery, Pork Fat, Sea Salt, Garlic, Rice Starch, Salt Pork (pork, sea salt), Spices)',
#   'name': 'Split Pea and Ham',
#   'protein': {'amount': '10.4g', 'percent': 20.0},
#   'sat_fat': None,
#   'serving_size': '8 fl. oz',
#   'sodium': {'amount': '719.1mg', 'percent': 36.0},
#   'sugars': {'amount': '4.2g'},
#   'total_carb': {'amount': '17.7g', 'percent': 6.0},
#   'total_fat': {'amount': '5.2g', 'percent': 7.0},
#   'trans_fat': None,
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 170,
#   'calories_from_fat': 94,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '2.8g', 'percent': 11.0},
#   'id': 10043,
#   'information': None,
#   'ingredients': 'Roasted Vegetable Soup (Vegetable Stock (contains mustard seed), Sweet Potatoes, Onion, Water, Potatoes, Zucchini, Savoy Cabbage, Celery, Carrots, Extra Virgin Olive Oil, Olive Oil, Parsley, Sea Salt, Garlic, Lemon Juice, Spices, Thyme.)',
#   'name': 'Roasted Vegetable Soup',
#   'protein': {'amount': '1.9g', 'percent': 4.0},
#   'sat_fat': None,
#   'serving_size': '8 oz',
#   'sodium': {'amount': '708.8mg', 'percent': 35.0},
#   'sugars': {'amount': '5.7g'},
#   'total_carb': {'amount': '18g', 'percent': 6.0},
#   'total_fat': {'amount': '10.4g', 'percent': 14.0},
#   'trans_fat': None,
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 177,
#   'calories_from_fat': 64,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '5.3g', 'percent': 21.0},
#   'id': 10044,
#   'information': None,
#   'ingredients': 'Tomato with Garden Vegetables (Diced Tomatoes (tomatoes, tomato juice, salt, citric acid), Water, Summer Squash, Zucchini, Onions, Carrots, Yellow Wax Beans, Green Beans, Celery, Olive Oil, Rice Flour, Scallions, Corn Oil, Spices, Sea Salt, Garlic.)',
#   'name': 'Tomato And Garden Vegetable Soup',
#   'protein': {'amount': '5.3g', 'percent': 10.0},
#   'sat_fat': None,
#   'serving_size': '8 oz',
#   'sodium': {'amount': '939.1mg', 'percent': 47.0},
#   'sugars': {'amount': '10.6g'},
#   'total_carb': {'amount': '26.6g', 'percent': 9.0},
#   'total_fat': {'amount': '7.1g', 'percent': 9.0},
#   'trans_fat': None,
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Soybeans', 'Tree Nuts', 'Wheat'],
#   'calories': 731,
#   'calories_from_fat': 277,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.5g', 'percent': 14.0},
#   'id': 10045,
#   'information': None,
#   'ingredients': 'Elbow Pasta (Ingredients: Semolina (Wheat), Durum Wheat Flour, Niacin, Iron (Ferrous Sulfate), Thiamine Mononitrate, Riboflavin, Folic Acid.), Organic Soy Milk (Organic Soymilk (Filtered Water, Organic Soybeans), Organic Cane Sugar, Calcium Carbonate, Sea Salt, Natural Flavors, Gellan Gum, Vitamin A Palmitate, Vitamin D2, Riboflavin (Vitamin B2), and Vitamin B12.), Vegan Cheddar (Filtered Water, Tapioca Starch, Coconut Oil, Expeller Pressed: Canola and/or Safflower Oil, Vegan Natural Flavors, Chickpea Protein, Salt, Potato Protein, Tricalcium Phosphate, Lactic Acid (Vegan), Konjac Gum, Yeast Extract, Xanthan Gum, Annatto Color, Turmeric Color, Inactive Yeast, Potassium Chloride.), Olive Oil (Refined Olive Oil, Extra Virgin Olive Oil.), All Purpose Flour (Bleached Wheat Flour, Malted Barley Flour, Niacin, Iron, Thiamine Mononitrate, Riboflavin, Folic Acid.), Yeast Flakes (Inactive Dry Yeast, Pyridoxine Hydrochloride (Vitamin B6), Thiamin Hydrochloride (Vitamin B1), Riboflavin (Vitamin B2), Folic Acid (Vitamin B9), Vitamin B12.), Onion Powder (Onion, silicon dioxide (anti-caking agent) MAY CONTAIN NATURALLY OCCURRING SULFUR COMPOUNDS.), Ground Cayenne Pepper (Dried Chilies), Whole Black Pepper (Black Peppercorns), Kosher Salt (Salt)',
#   'name': 'Vegan Macaroni and Cheese',
#   'protein': {'amount': '21.7g', 'percent': 43.0},
#   'sat_fat': {'amount': '3.3g', 'percent': 16.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '306.8mg', 'percent': 15.0},
#   'sugars': {'amount': '6.8g'},
#   'total_carb': {'amount': '97.1g', 'percent': 32.0},
#   'total_fat': {'amount': '30.7g', 'percent': 41.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Crustacean Shellfish', 'Fish', 'Milk', 'Wheat'],
#   'calories': 231,
#   'calories_from_fat': 142,
#   'cholesterol': {'amount': '83.3mg', 'percent': 28.0},
#   'dietary_fiber': {'amount': '0.9g', 'percent': 4.0},
#   'id': 10047,
#   'information': None,
#   'ingredients': 'Haddock Chowder (Fish Stock (water, cod bones, haddock bones, onions, celery, black pepper, thyme, mustard seed, bay leaves), Light Cream (milk, cream), Haddock, Potatoes, Onions, Celery, Butter (cream, salt), Wheat Flour, Sea Salt, Garlic, White Pepper, Pepper Sauce (distilled vinegar, red pepper, salt), Dried Thyme, Dried Dill)',
#   'name': 'Haddock Chowder',
#   'protein': {'amount': '11.1g', 'percent': 22.0},
#   'sat_fat': {'amount': '9.3g', 'percent': 46.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '592.5mg', 'percent': 30.0},
#   'sugars': {'amount': '3.7g'},
#   'total_carb': {'amount': '12g', 'percent': 4.0},
#   'total_fat': {'amount': '15.7g', 'percent': 21.0},
#   'trans_fat': {'amount': '0.5g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Milk', 'Wheat'],
#   'calories': 102,
#   'calories_from_fat': 21,
#   'cholesterol': {'amount': '27.8mg', 'percent': 9.0},
#   'dietary_fiber': {'amount': '0.9g', 'percent': 4.0},
#   'id': 10048,
#   'information': None,
#   'ingredients': 'Greek Chicken Orzo Soup (Chicken Stock (water, chicken bones, onions, celery, carrots, sea salt, garlic, parsley, white pepper, thyme, bay leaves, marjoram), Chicken (light meat), Onions, Carrots, Enriched Orzo (semolina [wheat], niacin, iron [ferrous sulfate], thiamin mononitrate, riboflavin, folic acid), Butter (cream, salt), Lemon Juice, Sea Salt, Parsley, Garlic, Spearmint, Dried Oregano, Dried Thyme, Bay Leaves, Black Pepper.)',
#   'name': 'Greek Chicken Orzo',
#   'protein': {'amount': '10.2g', 'percent': 20.0},
#   'sat_fat': {'amount': '1.4g', 'percent': 7.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '620.2mg', 'percent': 31.0},
#   'sugars': {'amount': '1.9g'},
#   'total_carb': {'amount': '11.1g', 'percent': 4.0},
#   'total_fat': {'amount': '2.3g', 'percent': 3.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Crustacean Shellfish', 'Fish', 'Milk', 'Wheat'],
#   'calories': 241,
#   'calories_from_fat': 150,
#   'cholesterol': {'amount': '101.8mg', 'percent': 34.0},
#   'dietary_fiber': {'amount': '0g'},
#   'id': 10049,
#   'information': None,
#   'ingredients': 'Lobster Bisque (Chicken Stock (Water, Chicken Bones, Onions, Celery, Carrots, Sea Salt, Garlic, Parsley, White Pepper, Thyme, Bay Leaves, Marjoram), Light Cream (Milk, cream), Butter (Cream, Salt), Wheat Flour, Water, Lobster Stock Lobster, Salt, cod), Tomato Puree (Tomatoes, Salt, Citric Acid), Sugar, Lobster Meat (Lobster, Water, Salt), Sherry Wine (Contains Sulfites), Rice Starch, Lobster Meat Lobster Meat, salt), Sea Salt, Clam Concentrate (Concentrated Clam Broth, Salt), White Pepper)',
#   'name': 'Lobster Bisque',
#   'protein': {'amount': '5.6g', 'percent': 11.0},
#   'sat_fat': {'amount': '10.2g', 'percent': 51.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '833.1mg', 'percent': 42.0},
#   'sugars': {'amount': '5.6g'},
#   'total_carb': {'amount': '16.7g', 'percent': 6.0},
#   'total_fat': {'amount': '16.7g', 'percent': 22.0},
#   'trans_fat': {'amount': '0.5g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Eggs', 'Wheat'],
#   'calories': 213,
#   'calories_from_fat': 92,
#   'cholesterol': {'amount': '55.5mg', 'percent': 19.0},
#   'dietary_fiber': {'amount': '0.9g', 'percent': 4.0},
#   'id': 10050,
#   'information': None,
#   'ingredients': 'Chicken & Dumpling Soup (Chicken Stock (Water, Chicken Bones, Onions, Celery, Carrots, Sea Salt, Garlic, Parsley, White Pepper, Thyme, Bay leaves, Marjoram), Chicken Meat (Dark and Light Meat), Dumplings (Durum Wheat Flour, Eggs, Wheat Gluten, Salt), Carrots, Onions, Celery, Chicken Fat, Wheat Flour, Sea Salt, Parsley, White Pepper, Nutmeg)',
#   'name': 'Chicken & Dumpling Soup',
#   'protein': {'amount': '12g', 'percent': 24.0},
#   'sat_fat': {'amount': '3.2g', 'percent': 16.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '648mg', 'percent': 32.0},
#   'sugars': {'amount': '1.9g'},
#   'total_carb': {'amount': '18.5g', 'percent': 6.0},
#   'total_fat': {'amount': '10.2g', 'percent': 14.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 70,
#   'calories_from_fat': 5,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 10052,
#   'information': None,
#   'ingredients': 'Sweet Potato & Kale Soup (Vegetable Stock, Vegetable base carrots tomatoes, Onions, Potatoes, Garlic, Sea Salt, Dextrose, Cane Sugar, Canola Oil, Spices, Turmeric Sweet Potatoes, Kidney Beans, Sea salt, Kombu Seaweed, Kale Celery, Carrots, Red Bell Pepper, Tomato Paste, Citric Acid, Corn Starch, Grape Vinegar, Sugar, Basil, Spices.)',
#   'name': 'Sweet Potato & Kale Soup',
#   'protein': {'amount': '2g', 'percent': 4.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '799.3mg', 'percent': 40.0},
#   'sugars': {'amount': '4g'},
#   'total_carb': {'amount': '15g', 'percent': 5.0},
#   'total_fat': {'amount': '0.5g', 'percent': 1.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Milk'],
#   'calories': 241,
#   'calories_from_fat': 109,
#   'cholesterol': {'amount': '37mg', 'percent': 12.0},
#   'dietary_fiber': {'amount': '1.9g', 'percent': 7.0},
#   'id': 10055,
#   'information': None,
#   'ingredients': 'Chicken Corn Chowder w/Pepper KC (Chicken Stock, Chicken (dark & light meat), Roasted Sweet Corn, Potatoes, Green Peppers, Light Cream (milk, cream), Red Peppers, Corn (corn, water, salt), Onions, Celery, Chicken Fat, Corn Oil, Rice Flour, Water, Corn Starch, Lemon Juice, Sea Salt, Sugar, Light Chili Powder (chili pepper, salt, spices, garlic powder), Granulated Garlic, Spices, Paprika (for color).)',
#   'name': 'Chicken and Corn Chowder Soup',
#   'protein': {'amount': '10.2g', 'percent': 20.0},
#   'sat_fat': {'amount': '3.7g', 'percent': 19.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '499.9mg', 'percent': 25.0},
#   'sugars': None,
#   'total_carb': {'amount': '24.1g', 'percent': 8.0},
#   'total_fat': {'amount': '12g', 'percent': 16.0},
#   'trans_fat': None,
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 185,
#   'calories_from_fat': 58,
#   'cholesterol': {'amount': '9.3mg', 'percent': 3.0},
#   'dietary_fiber': {'amount': '4.6g', 'percent': 19.0},
#   'id': 10056,
#   'information': None,
#   'ingredients': 'Portuguese Kale Sausage Soup KC (Chicken Stock, Kidney Beans, Kale, Potatoes, Uncured Linguica Sausage (Pork, Water, Salt, Paprika, Spices, Garlic, Natural Flavor; No Nitrate or Nitrite added except for those nitrites which naturally occur in natural flavor), Onions, Olive Oil, Garlic, Sea Salt, Spices, Paprika, Pepper Sauce (Distilled Vinegar, Red Pepper, Salt).)',
#   'name': 'Portuguese Kale and Sausage Soup',
#   'protein': {'amount': '12g', 'percent': 24.0},
#   'sat_fat': {'amount': '1.4g', 'percent': 7.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '490.6mg', 'percent': 25.0},
#   'sugars': None,
#   'total_carb': {'amount': '19.4g', 'percent': 6.0},
#   'total_fat': {'amount': '6.5g', 'percent': 9.0},
#   'trans_fat': None,
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Tree Nuts'],
#   'calories': 185,
#   'calories_from_fat': 42,
#   'cholesterol': {'amount': '23.1mg', 'percent': 8.0},
#   'dietary_fiber': {'amount': '3.7g', 'percent': 15.0},
#   'id': 10057,
#   'information': None,
#   'ingredients': 'Chicken Caribbean Soup KC (Chicken Stock (Water, Chicken Bones, Onions, Celery, Carrots, Sea Salt, Garlic, Parsley, White Pepper, Thyme, Bay Leaves, Marjoram), Chicken Meat, Sweet Potatoes, Diced Tomatoes , Tomato Juice, Salt, Citric Acid), Red Kidney Beans, Parboiled Long Grain Rice, Coconut Milk (Coconut, Water), Onions, Molasses, Rice Starch, Carrots, Garlic, Scallions, Tomato Paste (Tomatoes, Citric Acid), Olive Oil, Sea Salt, Jalapeno Peppers, Cilantro, Chicken Fat, Ginger, Black Pepper, Pepper Sauce (Distilled Vinegar, Red Pepper, Salt), Dried Thyme, Cinnamon, Nutmeg, Ground Allspice.)',
#   'name': 'Chicken Caribbean Jerk Soup',
#   'protein': {'amount': '10.2g', 'percent': 20.0},
#   'sat_fat': {'amount': '2.3g', 'percent': 12.0},
#   'serving_size': '8 oz',
#   'sodium': {'amount': '620.2mg', 'percent': 31.0},
#   'sugars': None,
#   'total_carb': {'amount': '28.7g', 'percent': 10.0},
#   'total_fat': {'amount': '4.6g', 'percent': 6.0},
#   'trans_fat': None,
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': ['Soybeans', 'Wheat'],
#   'calories': 220,
#   'calories_from_fat': 54,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3g', 'percent': 12.0},
#   'id': 10123,
#   'information': None,
#   'ingredients': 'CHEX MIX IND (Whole Wheat, Degermed Yellow Corn Meal, Enriched Flour (wheat flour, niacin, iron, thiamin mononitrate, riboflavin, folic acid), Vegetable Oil (soybean, rice bran and/or canola), Sugar, Rye Flour. Contains 2% or less of: Salt, Maltodextrin, Yeast, Spices, Color Added, Dextrose, Distilled Monoglycerides, Baking Soda, Yellow Corn Flour, Trisodium Phosphate, Calcium Carbonate, Autolyzed Yeast, Dried Onion, Dried Garlic, Hydrolyzed Soy Protein, Barley Malt Syrup, Fumaric Acid, Citric Acid, Caraway, Disodium Inosinate, Disodium Guanylate, Natural Flavor, Sodium Diacetate. Freshness Preserved by BHT.)',
#   'name': 'Chex Mix',
#   'protein': {'amount': '4g', 'percent': 8.0},
#   'sat_fat': {'amount': '1g', 'percent': 5.0},
#   'serving_size': '1 each',
#   'sodium': {'amount': '400mg', 'percent': 20.0},
#   'sugars': {'amount': '4g'},
#   'total_carb': {'amount': '38g', 'percent': 13.0},
#   'total_fat': {'amount': '6g', 'percent': 8.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Eggs', 'Milk', 'Soybeans', 'Wheat'],
#   'calories': 350,
#   'calories_from_fat': 325,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 10124,
#   'information': None,
#   'ingredients': 'BROWNIE (Sugar Flour (Bleached Wheat Flour, Malted Barley Flour, Niacin, Reduced iron, Potassium Bromate, Thiamin, Monitriate, Riboflavin, Folic Acid) Eggs, Soybean Oil, Cocoa Powder, Chocolate Liquor, Semi Swet choc chip (Sugar Chocolate) Liquor, Cocoa Butter, Soy Lecithin (An Emulisifier) Vanilla Water, Corn Syrup, Cornstarch, Baking Powder, Vanilla Salt Wheat, Milk, Eggs, Soy, )',
#   'name': 'Brownie',
#   'protein': {'amount': '5g', 'percent': 10.0},
#   'sat_fat': {'amount': '15g', 'percent': 75.0},
#   'serving_size': '1 each',
#   'sodium': {'amount': '105mg', 'percent': 5.0},
#   'sugars': {'amount': '26g'},
#   'total_carb': {'amount': '44g', 'percent': 15.0},
# ...
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3g', 'percent': 12.0},
#   'id': 171013,
#   'information': 'Kale is a nonheading member of the cabbage family and has been cultivated for over 2, 000 years.',
#   'ingredients': 'Green Kale (Kale), Kosher Salt (Salt), Ground Black Pepper (Black Pepper)',
#   'name': 'Sauteed Kale',
#   'protein': {'amount': '5g', 'percent': 10.0},
#   'sat_fat': {'amount': '0.1g', 'percent': 1.0},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '251.2mg', 'percent': 13.0},
#   'sugars': {'amount': '0g'},
#   'total_carb': {'amount': '15.2g', 'percent': 5.0},
#   'total_fat': {'amount': '1.1g', 'percent': 1.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 77,
#   'calories_from_fat': 4,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '4.7g', 'percent': 19.0},
#   'id': 171015,
#   'information': None,
#   'ingredients': 'Green Peas (Peas), Mushrooms Stems & Pieces (Mushrooms, Water, Salt, Citric Acid and Ascorbic Acid.), Ground Black Pepper (Black Pepper), Kosher Salt (Salt)',
#   'name': 'Sauteed Peas and Mushrooms',
#   'protein': {'amount': '5.3g', 'percent': 10.0},
#   'sat_fat': {'amount': '0.1g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '197.8mg', 'percent': 10.0},
#   'sugars': {'amount': '5.1g'},
#   'total_carb': {'amount': '13.8g', 'percent': 5.0},
#   'total_fat': {'amount': '0.4g', 'percent': 1.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 30,
#   'calories_from_fat': 3,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '1.7g', 'percent': 7.0},
#   'id': 171019,
#   'information': None,
#   'ingredients': 'Yellow Summer Squash (Summer Squash), Diced Red Pepper (Bell Peppers, Water, and Citric Acid.), Garlic (Garlic), Kosher Salt (Salt), Olive Oil (Refined Olive Oil, Extra Virgin Olive Oil.)',
#   'name': 'Sauteed Squash with Garlic and Red Pepper',
#   'protein': {'amount': '1.9g', 'percent': 4.0},
#   'sat_fat': {'amount': '0.1g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '135.1mg', 'percent': 7.0},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '6.3g', 'percent': 2.0},
#   'total_fat': {'amount': '0.3g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 55,
#   'calories_from_fat': 3,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.7g', 'percent': 15.0},
#   'id': 171021,
#   'information': None,
#   'ingredients': 'Sliced Carrots (Carrots), Parsley (Parsley)',
#   'name': 'Steamed Carrots',
#   'protein': {'amount': '1.2g', 'percent': 2.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '91.8mg', 'percent': 5.0},
#   'sugars': {'amount': '6.3g'},
#   'total_carb': {'amount': '12.7g', 'percent': 4.0},
#   'total_fat': {'amount': '0.3g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 41,
#   'calories_from_fat': 5,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.6g', 'percent': 15.0},
#   'id': 171022,
#   'information': None,
#   'ingredients': 'Collard Greens (Fresh Collard Greens), Onions (Onions), Vegetable Stock (Water, Vegetable Soup Base (Vegetables (Celery, Carrots, Onions), Salt, Sugar, Dehydrated Potatoes (Potatoes, Mono and Diglycerides, Sodium Acid Pyrophosphate, Citric Acid), Dextrose, Seasoning (Hydrolyzed Corn Protein, Yeast Extract), Flavoring, Disodium Inosinate, Disodium Guanylate, Beet Powder.)), Cider Vinegar (Distilled Vinegar (Diluted with water to 5% acidity), Water, Natural Flavor, Caramel Coloring.), Garlic (Garlic), Olive Oil (Refined Olive Oil, Extra Virgin Olive Oil.), Crushed Red Pepper (Red chile peppers)',
#   'name': 'Sauteed Collard Greens',
#   'protein': {'amount': '2.7g', 'percent': 5.0},
#   'sat_fat': {'amount': '0.1g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '55.1mg', 'percent': 3.0},
#   'sugars': {'amount': '1.5g'},
#   'total_carb': {'amount': '8.2g', 'percent': 3.0},
#   'total_fat': {'amount': '0.5g', 'percent': 1.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 47,
#   'calories_from_fat': 3,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.2g', 'percent': 13.0},
#   'id': 171023,
#   'information': None,
#   'ingredients': 'Carrots (Carrots), Kosher Salt (Salt), Parsley (Parsley), Ground Black Pepper (Black Pepper)',
#   'name': 'Steamed Carrots w/ Parsley',
#   'protein': {'amount': '1.1g', 'percent': 2.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '214.5mg', 'percent': 11.0},
#   'sugars': {'amount': '5.4g'},
#   'total_carb': {'amount': '11g', 'percent': 4.0},
#   'total_fat': {'amount': '0.3g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 69,
#   'calories_from_fat': 12,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '2.6g', 'percent': 10.0},
#   'id': 171027,
#   'information': 'The Vitamin K in Kale helps make four of the 13 proteins needed for blood clotting.',
#   'ingredients': 'Green Kale (Kale), Onions (Onions), Kosher Salt (Salt), Olive Oil (Refined Olive Oil, Extra Virgin Olive Oil.), Ground Black Pepper (Black Pepper)',
#   'name': 'Kale with Caramelized Onions',
#   'protein': {'amount': '3.9g', 'percent': 8.0},
#   'sat_fat': {'amount': '0.2g', 'percent': 1.0},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '339.8mg', 'percent': 17.0},
#   'sugars': {'amount': '0.7g'},
#   'total_carb': {'amount': '13g', 'percent': 4.0},
#   'total_fat': {'amount': '1.4g', 'percent': 2.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 99,
#   'calories_from_fat': 4,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '2g', 'percent': 8.0},
#   'id': 171029,
#   'information': None,
#   'ingredients': 'Corn on the Cob',
#   'name': 'Steamed Corn on the Cob',
#   'protein': {'amount': '3g', 'percent': 6.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '1 each',
#   'sodium': {'amount': '0mg'},
#   'sugars': {'amount': '3g'},
#   'total_carb': {'amount': '19.8g', 'percent': 7.0},
#   'total_fat': {'amount': '0.5g', 'percent': 1.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 29,
#   'calories_from_fat': 4,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '2.8g', 'percent': 11.0},
#   'id': 171034,
#   'information': None,
#   'ingredients': 'Spinach (Spinach), Kosher Salt (Salt), Ground Black Pepper (Black Pepper)',
#   'name': 'Steamed Spinach',
#   'protein': {'amount': '3.6g', 'percent': 7.0},
#   'sat_fat': {'amount': '0.1g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '170.7mg', 'percent': 9.0},
#   'sugars': {'amount': '0.5g'},
#   'total_carb': {'amount': '4.6g', 'percent': 2.0},
#   'total_fat': {'amount': '0.5g', 'percent': 1.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 65,
#   'calories_from_fat': None,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '4.3g', 'percent': 17.0},
#   'id': 171035,
#   'information': None,
#   'ingredients': 'Brussels Sprouts (Brussels Sprouts)',
#   'name': 'Brussels Sprouts',
#   'protein': {'amount': '4.3g', 'percent': 9.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '21.7mg', 'percent': 1.0},
#   'sugars': {'amount': '2.9g'},
#   'total_carb': {'amount': '11.6g', 'percent': 4.0},
#   'total_fat': {'amount': '0g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 29,
#   'calories_from_fat': 2,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.1g', 'percent': 12.0},
#   'id': 171036,
#   'information': None,
#   'ingredients': 'Green Beans (Green Beans)',
#   'name': 'Steamed Whole Green Beans',
#   'protein': {'amount': '1.5g', 'percent': 3.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '1mg'},
#   'sugars': {'amount': '1.3g'},
#   'total_carb': {'amount': '6.6g', 'percent': 2.0},
#   'total_fat': {'amount': '0.2g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 72,
#   'calories_from_fat': None,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '4.8g', 'percent': 19.0},
#   'id': 171038,
#   'information': None,
#   'ingredients': 'Brussels Sprouts (Brussels Sprouts)',
#   'name': 'Steamed Brussels Sprouts',
#   'protein': {'amount': '4.8g', 'percent': 9.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '24mg', 'percent': 1.0},
#   'sugars': {'amount': '3.2g'},
#   'total_carb': {'amount': '12.8g', 'percent': 4.0},
#   'total_fat': {'amount': '0g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 78,
#   'calories_from_fat': None,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.8g', 'percent': 15.0},
#   'id': 171043,
#   'information': None,
#   'ingredients': 'Peas & Onions (Green Peas, Pearl Onions and Salt.), Mint',
#   'name': 'Green Peas w/Onions & Mint',
#   'protein': {'amount': '5.2g', 'percent': 10.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '217.3mg', 'percent': 11.0},
#   'sugars': {'amount': '3.8g'},
#   'total_carb': {'amount': '14.2g', 'percent': 5.0},
#   'total_fat': {'amount': '0g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': False,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 36,
#   'calories_from_fat': 2,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.1g', 'percent': 12.0},
#   'id': 171045,
#   'information': 'Wilson Farms was founded by Irish immigrants in 1884 in Lexington, MA. Today, they farm an additional 500 acres in Litchfield, NH, where 40, 000 pounds of carrots are grown for HUDS annually.',
#   'ingredients': 'Carrots (Carrot), Dill',
#   'name': 'Locally Grown Carrots with Dill Sauce',
#   'protein': {'amount': '0.8g', 'percent': 2.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '60mg', 'percent': 3.0},
#   'sugars': {'amount': '3.6g'},
#   'total_carb': {'amount': '8.5g', 'percent': 3.0},
#   'total_fat': {'amount': '0.2g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 65,
#   'calories_from_fat': 37,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.5g', 'percent': 14.0},
#   'id': 171046,
#   'information': None,
#   'ingredients': 'Savoy Cabbage, Olive Oil (Refined Olive Oil, Extra Virgin Olive Oil, ), Kosher Salt (Salt), Crushed Red Pepper (Crushed Red Chilies)',
#   'name': 'Sauteed Savoy Cabbage',
#   'protein': {'amount': '2.3g', 'percent': 4.0},
#   'sat_fat': {'amount': '0.6g', 'percent': 3.0},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '50.6mg', 'percent': 3.0},
#   'sugars': {'amount': '2.6g'},
#   'total_carb': {'amount': '6.9g', 'percent': 2.0},
#   'total_fat': {'amount': '4.1g', 'percent': 6.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 43,
#   'calories_from_fat': 5,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.1g', 'percent': 12.0},
#   'id': 171047,
#   'information': 'The "sprouts" (small heads that resemble miniature cabbages) are produced in the leaf axils, starting at the base of the stem.',
#   'ingredients': 'Brussels Sprouts',
#   'name': 'Steamed Brussels Sprouts',
#   'protein': {'amount': '3g', 'percent': 6.0},
#   'sat_fat': {'amount': '0.1g', 'percent': 1.0},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '25mg', 'percent': 1.0},
#   'sugars': {'amount': '2.1g'},
#   'total_carb': {'amount': '8.5g', 'percent': 3.0},
#   'total_fat': {'amount': '0.6g', 'percent': 1.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 31,
#   'calories_from_fat': 2,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.4g', 'percent': 13.0},
#   'id': 171052,
#   'information': None,
#   'ingredients': 'Broccoli Florets (Broccoli), Cauliflower Florets (Cauliflower)',
#   'name': 'Steamed Broccoli and Cauliflower',
#   'protein': {'amount': '2.5g', 'percent': 5.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '146.4mg', 'percent': 7.0},
#   'sugars': {'amount': '1.8g'},
#   'total_carb': {'amount': '6.6g', 'percent': 2.0},
#   'total_fat': {'amount': '0.2g'},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  {'allergens': [],
#   'calories': 35,
#   'calories_from_fat': 3,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3g', 'percent': 12.0},
#   'id': 171054,
#   'information': None,
#   'ingredients': 'Carrots (Carrots), Broccoli Florets (Broccoli), Cauliflower Florets (Cauliflower)',
#   'name': 'Steamed Broccoli, Carrots and Cauliflower',
#   'protein': {'amount': '2.2g', 'percent': 4.0},
#   'sat_fat': {'amount': '0.1g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '41.8mg', 'percent': 2.0},
#   'sugars': {'amount': '2.5g'},
#   'total_carb': {'amount': '7.1g', 'percent': 2.0},
#   'total_fat': {'amount': '0.4g', 'percent': 1.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 87,
#   'calories_from_fat': 11,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '1.2g', 'percent': 5.0},
#   'id': 171056,
#   'information': None,
#   'ingredients': 'Chuckwagon Corn (Corn, Green Peppers, Onions and Red Peppers.)',
#   'name': 'Chuckwagon Corn',
#   'protein': {'amount': '3.7g', 'percent': 7.0},
#   'sat_fat': {'amount': '0g'},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '12.5mg', 'percent': 1.0},
#   'sugars': {'amount': '6.2g'},
#   'total_carb': {'amount': '21.2g', 'percent': 7.0},
#   'total_fat': {'amount': '1.2g', 'percent': 2.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': True},
#  {'allergens': ['Eggs', 'Milk', 'Soybeans'],
#   'calories': 237,
#   'calories_from_fat': 149,
#   'cholesterol': {'amount': '16.1mg', 'percent': 5.0},
#   'dietary_fiber': {'amount': '2.1g', 'percent': 8.0},
#   'id': 171057,
#   'information': None,
#   'ingredients': "Corn on the Cob, Sour Cream (Lite Cream, Whey, Cornstarch, Nonfat Milk, Sodium Phosphate, Guar gum, Carageenan, Sodium Cirtate, Locust Bean Gum.), Mayonnaise (Soybean Oil, Whole Eggs, Egg Yolks, , Water Distilled Vinegar Salt, Sugar, Dextrose, Lemon Juice concentrate , Calcium Disodium EDTA used to protect quality, Natural Flavors), Cotija Cheese (Pasteurized Whole Cow's Milk, Salt, Enzymes and Culture and powdered cellulose added)), Limes, Limes, Olive Oil (Refined Olive Oil, Extra Virgin Olive Oil, ), Cilantro, Ground Black Pepper, Kosher Salt (Salt)",
#   'name': 'Grilled Mexican Street Corn',
#   'protein': {'amount': '4.8g', 'percent': 9.0},
#   'sat_fat': {'amount': '4.5g', 'percent': 23.0},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '272.3mg', 'percent': 14.0},
#   'sugars': {'amount': '2.9g'},
#   'total_carb': {'amount': '17.8g', 'percent': 6.0},
#   'total_fat': {'amount': '16.6g', 'percent': 22.0},
#   'trans_fat': {'amount': '0.1g'},
#   'vegan': False,
#   'vegetarian': True},
#  {'allergens': [],
#   'calories': 77,
#   'calories_from_fat': 30,
#   'cholesterol': {'amount': '0mg'},
#   'dietary_fiber': {'amount': '3.3g', 'percent': 13.0},
#   'id': 171058,
#   'information': None,
#   'ingredients': 'Beets, Olive Oil (Refined Olive Oil, Extra Virgin Olive Oil, ), Ground Black Pepper, Kosher Salt (Salt)',
#   'name': 'Roasted Diced Beets',
#   'protein': {'amount': '1.9g', 'percent': 4.0},
#   'sat_fat': {'amount': '0.5g', 'percent': 2.0},
#   'serving_size': '4 oz',
#   'sodium': {'amount': '378.9mg', 'percent': 19.0},
#   'sugars': {'amount': '7.7g'},
#   'total_carb': {'amount': '11.2g', 'percent': 4.0},
#   'total_fat': {'amount': '3.3g', 'percent': 4.0},
#   'trans_fat': {'amount': '0g'},
#   'vegan': True,
#   'vegetarian': False},
#  ...]

# %%
new_recipes = {}
for item in recipes: 
    new_recipes[item["id"]] = {
        "name" : item["name"],
        "vegan" : item["vegan"],
        "vegetarian" : item["vegetarian"],
        "allergens" : item["allergens"],
        "calories" : item["calories"],
        "fiber" : item["dietary_fiber"],
        "sugars" : item["sugars"],
        "fat" : item["total_fat"],
        "carbs" : item["total_carb"],
        "protein" : item["protein"],
        "sodium" : item["sodium"],
        "serving_size" : item["serving_size"],
    }

with open('output.txt', 'w') as f:
    f.write(str(new_recipes))

# %%
import requests

# Get locations
response = requests.get("https://api.cs50.io/dining/locations")

# Convert JSON to list of dicts
locations = response.json()

print(locations)
better_locations={}
for item in locations: 
    better_locations[item["id"]] = item["name"]

print(better_locations)
# Out:
# [{'id': 3, 'name': 'Cronkhite Dining Room'}, {'id': 4, 'name': 'Dudley Cafe'}, {'id': 5, 'name': 'Cabot and Pforzheimer House'}, {'id': 7, 'name': 'Dunster and Mather House'}, {'id': 8, 'name': 'Quincy House'}, {'id': 9, 'name': 'Adams House'}, {'id': 14, 'name': 'Eliot and Kirkland House'}, {'id': 15, 'name': 'Lowell and Winthrop House'}, {'id': 16, 'name': 'Leverett House'}, {'id': 27, 'name': "Sebastian's Cafe"}, {'id': 29, 'name': 'Fly-By'}, {'id': 30, 'name': 'Annenberg Hall'}, {'id': 38, 'name': 'Currier House'}, {'id': 54, 'name': 'Northwest Cafe'}]
# {3: 'Cronkhite Dining Room', 4: 'Dudley Cafe', 5: 'Cabot and Pforzheimer House', 7: 'Dunster and Mather House', 8: 'Quincy House', 9: 'Adams House', 14: 'Eliot and Kirkland House', 15: 'Lowell and Winthrop House', 16: 'Leverett House', 27: "Sebastian's Cafe", 29: 'Fly-By', 30: 'Annenberg Hall', 38: 'Currier House', 54: 'Northwest Cafe'}
